# %% [raw]
# def read_data_from_csv():
#     follows=pd.read_csv('follows.csv')
#     return follows
#
#
# def data_cleaning():
#     #DO NOT REMOVE FOLLOWING LINE
#     #call remove_unwanted_columns() function to get dataframe
#     follows=read_data_from_csv()
#
#     #Remove Unwanted columns
#
#
#
#     #rename columns, only these columns are allowed in the dataset
#     # 1.	follower_id
#     # 2.	followee_id
#     # 3.	created_at
#
#     #export cleaned Dataset to newcsv file named "follows_cleaned.csv"
#     follows.to_csv('follows_cleaned.csv')
#     return follows
#
#
# #Do not Delete the Following function
# def task_runner():
#     data_cleaning()
#
# task_runner()

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
def read_data_from_csv():
    follows=pd.read_csv(r"C:\Users\Ramakrishna\Desktop\Instant Project\follows.csv")
    return follows

# %%
read_data_from_csv()
# Out:
#       follower  followee       created time  is follower active  \
# 0            2          1  13-04-2023 08:04                   1
# 1            2          3  13-04-2023 08:04                   0
# 2            2          4  13-04-2023 08:04                   0
# 3            2          5  13-04-2023 08:04                   0
# 4            2          6  13-04-2023 08:04                   1
# ...        ...        ...               ...                 ...
# 7618       100         95  13-04-2023 08:04                   1
# 7619       100         96  13-04-2023 08:04                   1
# 7620       100         97  13-04-2023 08:04                   1
# 7621       100         98  13-04-2023 08:04                   1
# 7622       100         99  13-04-2023 08:04                   1
#
#      followee Acc status
# 0                Private
# 1                private
# 2                 public
# 3                private
# 4                private
# ...                  ...
# 7618              public
# 7619             Private
# 7620             private
# 7621              public
# 7622             private
#
# [7623 rows x 5 columns]

# %%
read_data_from_csv().columns
# Out:
# Index(['follower', 'followee ', 'created time', 'is follower active',
#        'followee Acc status'],
#       dtype='object')

# %%
def data_cleaning():
    #DO NOT REMOVE FOLLOWING LINE
    #call remove_unwanted_columns() function to get dataframe
    follows=read_data_from_csv()

    #Remove Unwanted columns
    follows.drop(['is follower active','followee Acc status'],axis=1,inplace=True)
    
    
    #rename columns, only these columns are allowed in the dataset
    # 1.	follower_id
    # 2.	followee_id
    # 3.	created_at
    column_name={'follower':'follower_id','followee ':'followee_id','created time':'created_at'}
    follows=follows.rename(columns=column_name)
    
    #export cleaned Dataset to newcsv file named "follows_cleaned.csv"
    follows.to_csv('follows_cleaned.csv')
    return follows

# %%
data_cleaning()
# Out:
#       follower_id  followee_id        created_at
# 0               2            1  13-04-2023 08:04
# 1               2            3  13-04-2023 08:04
# 2               2            4  13-04-2023 08:04
# 3               2            5  13-04-2023 08:04
# 4               2            6  13-04-2023 08:04
# ...           ...          ...               ...
# 7618          100           95  13-04-2023 08:04
# 7619          100           96  13-04-2023 08:04
# 7620          100           97  13-04-2023 08:04
# 7621          100           98  13-04-2023 08:04
# 7622          100           99  13-04-2023 08:04
#
# [7623 rows x 3 columns]
